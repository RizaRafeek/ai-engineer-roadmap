# %%
import google.generativeai as genai 
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.embeddings import HuggingFaceEmbeddings
from langchaain.vectorstores import FAISS   #it is the most cheapest free forever vector db out there
from langchain.docstore.document import document        #need document because to a se they need metadata like the data (like who asked it who are they etc, for that we need document structure instead of plain text)
from langchain.agents iport initialize_agent, Tool, AgentType

# %%
embeddings = HuggingFaceEmbeddings(model_name"sentence-transformers/all-MiniLM-L6-v2")

# %%
#convert  to emb -> save in vector db
vectorstore = FAISS.from_documents(docs, embeddings)     #docs -> embedding
